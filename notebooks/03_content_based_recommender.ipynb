# %% [markdown]
# # Content-Based Recommender (TF‑IDF) — No Train/Test Split
# This notebook builds a pure **content-based** recommender using only the course catalog (`data/processed/courses_with_id.csv`).
# It includes a few **sample tests** (interest prompts → recommended courses) and prints short, human-readable explanations based on overlapping keywords.
#
# Why no train/test split here? Because offline metrics like Precision@k / NDCG@k require held-out user interactions. This notebook focuses on a working baseline + sanity checks.

# %%
# 1) Imports + Load catalog
from __future__ import annotations

from pathlib import Path
import re
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

ROOT = Path.cwd()
CATALOG_PATH = ROOT.parent / "data" / "processed" / "courses_with_id.csv"
assert CATALOG_PATH.exists(), f"Missing: {CATALOG_PATH}"

df = pd.read_csv(CATALOG_PATH)
print("Catalog shape:", df.shape)
print("Columns:", list(df.columns))
df.head(3)
# Out:
# Catalog shape: (3408, 10)
# Columns: ['course_id', 'Course Name', 'University', 'Difficulty Level', 'Course Rating', 'Course URL', 'Course Description', 'skills_cleaned', 'difficulty_numeric', 'recommended_grade']
#    course_id                                        Course Name  \
# 0          0  Write A Feature Length Screenplay For Film Or ...
# 1          1  Business Strategy: Business Model Canvas Analy...
# 2          2                      Silicon Thin Film Solar Cells
#
#                   University Difficulty Level  Course Rating  \
# 0  Michigan State University         Beginner            4.8
# 1   Coursera Project Network         Beginner            4.8
# 2        �cole Polytechnique         Advanced            4.1
#
#                                           Course URL  \
# 0  https://www.coursera.org/learn/write-a-feature...
# 1  https://www.coursera.org/learn/canvas-analysis...
# 2  https://www.coursera.org/learn/silicon-thin-fi...
#
#                                   Course Description  \
# 0  Write a Full Length Feature Film Script  In th...
# 1  By the end of this guided project, you will be...
# 2  This course consists of a general presentation...
#
#                                       skills_cleaned  difficulty_numeric  \
# 0  peering  film  dialogue  creative writing  wri...                   1
# 1  finance  business plan  persona (user experien...                   1
# 2  chemistry  physics  solar energy  film  lambda...                   3
#
#    recommended_grade
# 0                 70
# 1                 70
# 2                 85

# %%
# 2) Build a text field for each course
TEXT_COLS_PREFERRED = ["Course Name", "University", "Course Description", "skills_cleaned"]
missing = [c for c in TEXT_COLS_PREFERRED if c not in df.columns]
if missing:
    print("Warning: missing expected columns:", missing)

def clean_text(s: str) -> str:
    s = str(s) if s is not None else ""
    s = s.replace("\uFFFD", " ")  # replacement char
    s = re.sub(r"\s+", " ", s).strip().lower()
    return s

def canonical_difficulty(x: str) -> str | None:
    """Map difficulty strings to a stable token (beginner/intermediate/advanced)."""
    if x is None or (isinstance(x, float) and np.isnan(x)):
        return None
    s = clean_text(x)
    if not s:
        return None
    if "beginner" in s:
        return "beginner"
    if "intermediate" in s:
        return "intermediate"
    if "advanced" in s:
        return "advanced"
    # fall back to cleaned raw string if it's something unexpected
    return s

def build_course_text(row) -> str:
    parts = []
    for c in TEXT_COLS_PREFERRED:
        if c in row and pd.notna(row[c]):
            parts.append(clean_text(row[c]))

    # Optional: add canonical difficulty token for consistency
    if "Difficulty Level" in df.columns and "Difficulty Level" in row and pd.notna(row["Difficulty Level"]):
        d = canonical_difficulty(row["Difficulty Level"])
        if d:
            parts.append(f"difficulty_{d}")

    return " \n".join([p for p in parts if p])

df["_text"] = df.apply(build_course_text, axis=1)
empty_rate = (df["_text"].str.len() == 0).mean()
print("Empty _text rate:", round(float(empty_rate), 4))
df[["course_id","Course Name","skills_cleaned"]].head(3)
# Out:
# Empty _text rate: 0.0
#    course_id                                        Course Name  \
# 0          0  Write A Feature Length Screenplay For Film Or ...
# 1          1  Business Strategy: Business Model Canvas Analy...
# 2          2                      Silicon Thin Film Solar Cells
#
#                                       skills_cleaned
# 0  peering  film  dialogue  creative writing  wri...
# 1  finance  business plan  persona (user experien...
# 2  chemistry  physics  solar energy  film  lambda...

# %%
# 3) Fit TF-IDF over course texts
vectorizer = TfidfVectorizer(
    stop_words="english",
    ngram_range=(1, 2),
    min_df=2,
    max_df=0.9,
)
X = vectorizer.fit_transform(df["_text"])
print("TF-IDF matrix:", X.shape)
print("Vocab size:", len(vectorizer.vocabulary_))
# Out:
# TF-IDF matrix: (3408, 53323)
# Vocab size: 53323

# %%
# 4) Recommender helpers (by interest text, or by similar course)
FEATURE_NAMES = np.array(vectorizer.get_feature_names_out())

def top_overlap_terms(query_vec, item_vec, top_n=8):
    """Return top terms contributing to similarity via overlap of TF-IDF weights."""
    # element-wise product keeps only overlapping features; stays sparse
    overlap = query_vec.multiply(item_vec)
    if overlap.nnz == 0:
        return []
    # pick top weights among non-zeros
    coo = overlap.tocoo()
    idx = np.argsort(coo.data)[::-1][:top_n]
    feat_idx = coo.col[idx]
    return FEATURE_NAMES[feat_idx].tolist()

def _minmax_0_1(scores: np.ndarray) -> np.ndarray:
    scores = np.asarray(scores, dtype=float)
    if scores.size == 0:
        return scores
    lo = float(np.min(scores))
    hi = float(np.max(scores))
    if hi <= lo:
        return np.ones_like(scores)
    return (scores - lo) / (hi - lo)

def recommend_by_interest_text(
    query: str,
    top_k=10,
    *,
    filter_zero: bool = True,
    normalize_scores: bool = False,
    explain_top_n_terms: int = 8,
 ):
    """Recommend courses for a free-text interest query.

    - `filter_zero=True` returns only courses with non-zero similarity (sparse top-k).
    - `normalize_scores=True` min-max normalizes returned scores to [0, 1].
    """
    query = clean_text(query)
    qv = vectorizer.transform([query])

    if filter_zero:
        # Sparse dot product stays sparse; only overlapping courses become non-zero.
        sims_sparse = (qv @ X.T).tocsr()
        if sims_sparse.nnz == 0:
            cols = ["course_id", "Course Name", "University", "Difficulty Level", "Course Rating", "Course URL", "skills_cleaned", "score", "why_keywords"]
            return pd.DataFrame(columns=cols)
        idxs = sims_sparse.indices
        vals = sims_sparse.data
        order = np.argsort(vals)[::-1]
        order = order[: min(int(top_k), order.size)]
        top_idx = idxs[order]
        top_scores = vals[order]
    else:
        # Dense fallback (includes zeros); ok for small catalogs / debugging.
        sims = cosine_similarity(qv, X).ravel()
        top_idx = np.argsort(sims)[::-1][:top_k]
        top_scores = sims[top_idx]

    out = df.loc[top_idx, ["course_id", "Course Name", "University", "Difficulty Level", "Course Rating", "Course URL", "skills_cleaned"]].copy()
    out["score"] = top_scores
    if normalize_scores:
        out["score"] = _minmax_0_1(out["score"].to_numpy())

    # explanations
    expl = []
    for i in top_idx:
        terms = top_overlap_terms(qv, X[int(i)], top_n=explain_top_n_terms)
        expl.append(", ".join(terms))
    out["why_keywords"] = expl
    return out.reset_index(drop=True)

def recommend_similar_to_course(
    course_id: int,
    top_k=10,
    *,
    filter_zero: bool = True,
    normalize_scores: bool = False,
 ):
    if "course_id" not in df.columns:
        raise ValueError("course_id column not found in catalog")
    matches = df.index[df["course_id"] == course_id].tolist()
    if not matches:
        raise ValueError(f"course_id {course_id} not found")
    i0 = int(matches[0])

    if filter_zero:
        sims_sparse = (X[i0] @ X.T).tocsr()
        if sims_sparse.nnz == 0:
            cols = ["course_id", "Course Name", "University", "Difficulty Level", "Course Rating", "Course URL", "skills_cleaned", "score"]
            return pd.DataFrame(columns=cols)
        idxs = sims_sparse.indices
        vals = sims_sparse.data
        # exclude itself (if present among nonzeros)
        keep = idxs != i0
        idxs = idxs[keep]
        vals = vals[keep]
        if vals.size == 0:
            cols = ["course_id", "Course Name", "University", "Difficulty Level", "Course Rating", "Course URL", "skills_cleaned", "score"]
            return pd.DataFrame(columns=cols)
        order = np.argsort(vals)[::-1]
        order = order[: min(int(top_k), order.size)]
        top_idx = idxs[order]
        top_scores = vals[order]
    else:
        sims = cosine_similarity(X[i0], X).ravel()
        sims[i0] = -1
        top_idx = np.argsort(sims)[::-1][:top_k]
        top_scores = sims[top_idx]

    out = df.loc[top_idx, ["course_id", "Course Name", "University", "Difficulty Level", "Course Rating", "Course URL", "skills_cleaned"]].copy()
    out["score"] = top_scores
    if normalize_scores:
        out["score"] = _minmax_0_1(out["score"].to_numpy())
    return out.reset_index(drop=True)

# %% [markdown]
# ## Optional: Precompute top-K similar courses (faster repeated queries)
# If you call `recommend_similar_to_course` a lot, you can precompute neighbors once using `NearestNeighbors(metric="cosine")` and then do O(k) lookups.

# %%
from sklearn.neighbors import NearestNeighbors

# Fit neighbors on TF-IDF (cosine distance; smaller is more similar)
TOPK_NEIGHBORS = 50  # precompute this many neighbors per course
nn = NearestNeighbors(n_neighbors=TOPK_NEIGHBORS + 1, metric="cosine", algorithm="brute")
nn.fit(X)

# Indices and distances for each course (includes self at position 0)
distances, indices = nn.kneighbors(X, return_distance=True)
similarities = 1.0 - distances

def fast_similar_to_course(course_id: int, top_k=10):
    matches = df.index[df["course_id"] == course_id].tolist()
    if not matches:
        raise ValueError(f"course_id {course_id} not found")
    i0 = int(matches[0])

    neigh_idx = indices[i0]
    neigh_sim = similarities[i0]

    # drop self (first entry)
    neigh_idx = neigh_idx[1:]
    neigh_sim = neigh_sim[1:]

    top_k = min(int(top_k), len(neigh_idx))
    top_idx = neigh_idx[:top_k]
    top_scores = neigh_sim[:top_k]

    out = df.loc[top_idx, ["course_id", "Course Name", "University", "Difficulty Level", "Course Rating", "Course URL", "skills_cleaned"]].copy()
    out["score"] = top_scores
    return out.reset_index(drop=True)

# Example usage:
# display(fast_similar_to_course(int(df.loc[0, "course_id"]), top_k=8))

# %% [markdown]
# ## Sample tests (no split)
# These are simple sanity checks: provide an interest prompt and inspect the top recommendations + `why_keywords` explanations.

# %%
tests = [
    "biology ecology environment design drawing architecture landscape",
    "data analysis python statistics machine learning visualization",
    "finance accounting budgeting business strategy management",
    "creative writing storytelling film screenwriting dialogue",
    "health nutrition fitness mental wellbeing psychology",
    "islamic studies quran hadith fiqh theology",
    "python development programming coding software engineering",
]

for q in tests:
    print("\n" + "="*90)
    print("QUERY:", q)
    recs = recommend_by_interest_text(q, top_k=5)
    display(recs)
# Out:
# ==========================================================================================
# QUERY: biology ecology environment design drawing architecture landscape
#    course_id                                        Course Name  \
# 0       2382                        Ecology: from cells to Gaia
# 1         93                                Making Architecture
# 2       2702         Systems Biology and Biotechnology Capstone
# 3       1678       Ecology: Ecosystem Dynamics and Conservation
# 4       1239  Biological Diversity (Theories, Measures and D...
#
#                                  University Difficulty Level  Course Rating  \
# 0  National Research Tomsk State University     Intermediate            4.3
# 1                        IE Business School     Intermediate            4.8
# 2   Icahn School of Medicine at Mount Sinai         Advanced            4.2
# 3        American Museum of Natural History         Beginner            4.8
# 4  National Research Tomsk State University     Intermediate            4.2
#
#                                           Course URL  \
# 0             https://www.coursera.org/learn/ecology
# 1  https://www.coursera.org/learn/making-architec...
# 2  https://www.coursera.org/learn/systems-biology...
# 3  https://www.coursera.org/learn/ecology-conserv...
# 4  https://www.coursera.org/learn/biological-dive...
#
#                                       skills_cleaned     score  \
# 0  ecosystems  ecosystem  sustainability  ecology...  0.242658
# 1          modeling  architecture  thought  analysis  0.168555
# 2     computational biology  systems design  biology  0.153731
# 3  ecology  ecosystems  thought  biology  biodive...  0.152531
# 4  ecology  biodiversity  evolution  climate chan...  0.150420
#
#                         why_keywords
# 0      ecology, biology, environment
# 1  architecture, design, environment
# 2                    biology, design
# 3                   ecology, biology
# 4  ecology, biology ecology, biology
# ==========================================================================================
# QUERY: data analysis python statistics machine learning visualization
#    course_id                                       Course Name  \
# 0       1614                         Exploratory Data Analysis
# 1       1995                         Data Analysis with Python
# 2       2473          Statistical Data Visualization in Python
# 3       2280  Exploratory Data Analysis With Python and Pandas
# 4       2464          Introduction to Applied Machine Learning
#
#                                University Difficulty Level  Course Rating  \
# 0                Coursera Project Network         Beginner            4.3
# 1                                     IBM       Conversant            4.6
# 2                Coursera Project Network         Advanced            3.7
# 3                Coursera Project Network         Beginner            4.7
# 4  Alberta Machine Intelligence Institute     Intermediate            4.7
#
#                                           Course URL  \
# 0  https://www.coursera.org/learn/exploratory-dat...
# 1  https://www.coursera.org/learn/data-analysis-w...
# 2  https://www.coursera.org/learn/statistical-vis...
# 3  https://www.coursera.org/learn/exploratory-dat...
# 4  https://www.coursera.org/learn/machine-learnin...
#
#                                       skills_cleaned     score  \
# 0  general statistics  exploratory data analysis ...  0.340398
# 1  data model  regression  python programming  re...  0.284830
# 2  project mine  chart  project  computer graphic...  0.278912
# 3  data analysis  analysis  exploratory data anal...  0.262140
# 4  algorithms  test set  machine learning  ordere...  0.259973
#
#                                         why_keywords
# 0  data analysis, analysis, data, visualization, ...
# 1  data analysis, analysis python, data, analysis...
# 2  visualization, statistics machine, python, mac...
# 3  data analysis, analysis, python, analysis pyth...
# 4  machine, machine learning, learning, data, dat...
# ==========================================================================================
# QUERY: finance accounting budgeting business strategy management
#    course_id                                       Course Name  \
# 0        630           Finance for Non-Financial Professionals
# 1       2984                              Strategy Formulation
# 2       1819                        Advanced Business Strategy
# 3        829                      Financial Reporting Capstone
# 4       1120  Core Concepts of Accounting � Numbers and People
#
#                                    University Difficulty Level  Course Rating  \
# 0            University of California, Irvine       Conversant            4.5
# 1                  Copenhagen Business School         Beginner            4.5
# 2                      University of Virginia         Beginner            4.7
# 3  University of Illinois at Urbana-Champaign         Advanced            4.5
# 4  Moscow Institute of Physics and Technology         Advanced            4.8
#
#                                           Course URL  \
# 0  https://www.coursera.org/learn/finance-for-non...
# 1  https://www.coursera.org/learn/strategy-formul...
# 2  https://www.coursera.org/learn/uva-darden-Adva...
# 3  https://www.coursera.org/learn/financial-repor...
# 4  https://www.coursera.org/learn/core-concepts-o...
#
#                                       skills_cleaned     score  \
# 0  analysis  cost  finance  financial statement  ...  0.285476
# 1  leadership and management  business strategy  ...  0.263314
# 2  strategy  business strategy  strategic managem...  0.252424
# 3           finance  accounting  financial statement  0.210628
# 4  inventory  cost  financial accounting  finance...  0.208611
#
#                                         why_keywords
# 0  finance, budgeting, accounting, finance accoun...
# 1  business strategy, strategy, business, management
# 2  strategy, business strategy, business, management
# 3            accounting, finance accounting, finance
# 4          accounting, finance, business, management
# ==========================================================================================
# QUERY: creative writing storytelling film screenwriting dialogue
#    course_id                                        Course Name  \
# 0       2355                    Writing Stories About Ourselves
# 1       1411  Creative Writing: The Craft of Setting and Des...
# 2       2911                           Writing a Personal Essay
# 3        330  Memoir and Personal Essay: Managing Your Relat...
# 4        523              Writing in First Person Point of View
#
#             University Difficulty Level  Course Rating  \
# 0  Wesleyan University         Advanced            3.7
# 1  Wesleyan University         Advanced            4.7
# 2  Wesleyan University         Advanced            4.4
# 3  Wesleyan University         Advanced            4.2
# 4  Wesleyan University         Advanced            4.6
#
#                                           Course URL  \
# 0  https://www.coursera.org/learn/writing-about-o...
# 1  https://www.coursera.org/learn/craft-of-settin...
# 2      https://www.coursera.org/learn/personal-essay
# 3  https://www.coursera.org/learn/memoir-reader-r...
# 4    https://www.coursera.org/learn/first-person-pov
#
#                                       skills_cleaned     score  \
# 0  film  writing  essay writing  storytelling  cr...  0.425466
# 1  copywriting  storytelling  human learning  fil...  0.314068
# 2  chemistry  film  essay writing  creative writi...  0.303050
# 3  relative change and difference  film  essay wr...  0.287111
# 4  poetry writing  film  storytelling  writing  c...  0.246754
#
#                                         why_keywords
# 0  dialogue, storytelling, film, creative, writin...
# 1  creative writing, creative, writing, storytell...
# 2  creative writing, writing, writing storytellin...
# 3  writing, writing storytelling, creative writin...
# 4  writing, storytelling, creative writing, film,...
# ==========================================================================================
# QUERY: health nutrition fitness mental wellbeing psychology
#    course_id                                        Course Name  \
# 0        409              Positive Psychiatry and Mental Health
# 1        689    The Social Context of Mental Health and Illness
# 2        422                     Biohacking Your Brain's Health
# 3       2710  Hacking Exercise For Health. The surprising ne...
# 4       2161  Major Depression in the Population: A Public H...
#
#                  University Difficulty Level  Course Rating  \
# 0  The University of Sydney     Intermediate            4.7
# 1     University of Toronto         Beginner            4.5
# 2          Emory University         Beginner            4.7
# 3       McMaster University     Intermediate            4.7
# 4  Johns Hopkins University     Intermediate            4.7
#
#                                           Course URL  \
# 0  https://www.coursera.org/learn/positive-psychi...
# 1       https://www.coursera.org/learn/mental-health
# 2  https://www.coursera.org/learn/biohacking-your...
# 3  https://www.coursera.org/learn/hacking-exercis...
# 4  https://www.coursera.org/learn/public-health-d...
#
#                                       skills_cleaned     score  \
# 0  leadership and management  mindfulness  stress...  0.308314
# 1     mental health  social psychology  anthropology  0.283688
# 2  neuroscience  nutrition  exercise  mental heal...  0.237779
# 3         protein  training  mental health  exercise  0.231600
# 4  public health  mental health  clinical study d...  0.203070
#
#                             why_keywords
# 0  mental, health, wellbeing, psychology
# 1             mental, health, psychology
# 2     health, nutrition, fitness, mental
# 3                fitness, health, mental
# 4                         mental, health
# ==========================================================================================
# QUERY: islamic studies quran hadith fiqh theology
#    course_id                                        Course Name  \
# 0       3210       Constitutional Struggles in the Muslim World
# 1       2962      Toledo: Deciphering Secrets of Medieval Spain
# 2       3330                   Re-imaging God in Korean Context
# 3        462  Understanding Medical Research: Your Facebook ...
# 4       2777                    Intellectual Humility: Practice
#
#                       University Difficulty Level  Course Rating  \
# 0       University of Copenhagen         Beginner            4.8
# 1  University of Colorado System         Advanced            4.2
# 2              Yonsei University     Intermediate            4.7
# 3                Yale University         Beginner            4.9
# 4    The University of Edinburgh         Beginner            4.6
#
#                                           Course URL  \
# 0        https://www.coursera.org/learn/muslim-world
# 1  https://www.coursera.org/learn/toledo-decipher...
# 2  https://www.coursera.org/learn/god-korean-context
# 3    https://www.coursera.org/learn/medical-research
# 4  https://www.coursera.org/learn/intellectual-hu...
#
#                                       skills_cleaned     score  \
# 0  law  international law  religion  reason  econ...  0.156710
# 1  culture  history  poetry writing  r&d manageme...  0.137719
# 2          religion  interpretation  korean language  0.111337
# 3  experiment  relative change and difference  ge...  0.065896
# 4  intellectual  educational psychology  evaluati...  0.054278
#
#         why_keywords
# 0            islamic
# 1            islamic
# 2           theology
# 3            studies
# 4  theology, islamic
# ==========================================================================================
# QUERY: python development programming coding software engineering
#    course_id                                        Course Name  \
# 0         61           Python Tricks and Hacks for Productivity
# 1       2263                               Python Data Analysis
# 2        722                        Python Data Representations
# 3       1137   Software Development Processes and Methodologies
# 4       3386  Requirements Gathering for Secure Software Dev...
#
#                       University Difficulty Level  Course Rating  \
# 0       Coursera Project Network         Advanced            4.1
# 1                Rice University         Advanced            4.6
# 2                Rice University         Advanced            4.7
# 3        University of Minnesota         Advanced            4.4
# 4  University of Colorado System         Beginner            4.6
#
#                                           Course URL  \
# 0        https://www.coursera.org/learn/python-hacks
# 1     https://www.coursera.org/learn/python-analysis
# 2  https://www.coursera.org/learn/python-represen...
# 3  https://www.coursera.org/learn/software-processes
# 4  https://www.coursera.org/learn/requirements-ga...
#
#                                       skills_cleaned     score  \
# 0  computer programming  python programming  soft...  0.215293
# 1  data visualization  jpeg  python programming  ...  0.193238
# 2  python programming  process  iteration  comput...  0.189139
# 3  modeling  software  scrum (software developmen...  0.172159
# 4  software  agile software development  software...  0.166632
#
#                                         why_keywords
# 0  python, coding, software engineering, software...
# 1  python, python development, programming, devel...
# 2  python, python development, programming, devel...
# 3  software, software engineering, development, e...
# 4  software, development, software engineering, e...

# %%
# Similar-items test: pick a random course and find close neighbors
rng = np.random.default_rng(42)
i = int(rng.integers(0, len(df)))
seed = df.loc[i]
print("Seed course:")
display(seed[["course_id","Course Name","University","Difficulty Level","Course Rating","skills_cleaned"]])

print("\nMost similar courses:")
display(recommend_similar_to_course(int(seed["course_id"]), top_k=8))
# Out:
# Seed course:
# course_id                                                         304
# Course Name                                    Astro 101: Black Holes
# University                                      University of Alberta
# Difficulty Level                                             Beginner
# Course Rating                                                     4.8
# skills_cleaned      path (variable)  angular  energy  materials  p...
# Name: 304, dtype: object
# Most similar courses:
#    course_id                                        Course Name  \
# 0       1797                              The Evolving Universe
# 1       2528     Introduction into General Theory of Relativity
# 2        200                              Data-driven Astronomy
# 3        753       The Sun and the Total Eclipse of August 2017
# 4       1809                             Analyzing the Universe
# 5        445  AstroTech: The Science and Technology behind A...
# 6       2469               Physical Basics of Quantum Computing
# 7        981                       Image Processing with Python
#
#                                           University Difficulty Level  \
# 0                                            Caltech     Intermediate
# 1  National Research University Higher School of ...         Advanced
# 2                           The University of Sydney         Advanced
# 3                     University of Colorado Boulder         Beginner
# 4         Rutgers the State University of New Jersey         Beginner
# 5                        The University of Edinburgh         Beginner
# 6                  Saint Petersburg State University     Intermediate
# 7                           Coursera Project Network         Beginner
#
#    Course Rating                                         Course URL  \
# 0            4.6    https://www.coursera.org/learn/evolvinguniverse
# 1            4.6  https://www.coursera.org/learn/general-relativity
# 2            4.8  https://www.coursera.org/learn/data-driven-ast...
# 3            4.6             https://www.coursera.org/learn/eclipse
# 4            4.6             https://www.coursera.org/learn/analyze
# 5            4.7  https://www.coursera.org/learn/astronomy-techn...
# 6            4.2  https://www.coursera.org/learn/physical-basis-...
# 7            4.2  https://www.coursera.org/learn/image-processin...
#
#                                       skills_cleaned     score
# 0  astronomy  evolution  process  theory of relat...  0.256373
# 1  theory of relativity  astronomy  tailored acce...  0.212041
# 2  computer programming  python programming  sql ...  0.175112
# 3  planning  solar systems  angular  process  rec...  0.157140
# 4  astronomy  sources  mechanical engineering  qu...  0.155273
# 5  solar systems  energy  astronomy  chemistry  p...  0.151155
# 6                         quantum mechanics  physics  0.113803
# 7  opencv  image processing  project  python prog...  0.102313

# %% [markdown]
# ## What to look for in the sample tests
# - Does `why_keywords` match your query intent?
# - Are recommendations diverse enough, or too repetitive?
# - If everything looks "samey", increase `ngram_range`, include more columns, or lower `min_df`.

# %% [markdown]
# ## Export model artifacts
# This saves the fitted TF‑IDF vectorizer and the course TF‑IDF matrix so you can reuse them in the API without refitting.
# It also saves a minimal course table needed to map indices back to course metadata.

# %%
from pathlib import Path
import json
import joblib

EXPORT_DIR = Path.cwd().parent / "models" / "content_based"
EXPORT_DIR.mkdir(parents=True, exist_ok=True)

artifacts_path = EXPORT_DIR / "tfidf_artifacts.joblib"
meta_path = EXPORT_DIR / "tfidf_metadata.json"

# Keep only what we need to serve recommendations
catalog_min = df[["course_id", "Course Name", "University", "Difficulty Level", "Course Rating", "Course URL", "skills_cleaned"]].copy()

joblib.dump(
    {
        "vectorizer": vectorizer,
        "X": X,
        "catalog": catalog_min,
    },
    artifacts_path,
    compress=3,
)

meta = {
    "created_utc": __import__("datetime").datetime.utcnow().isoformat() + "Z",
    "catalog_rows": int(len(df)),
    "tfidf_shape": [int(X.shape[0]), int(X.shape[1])],
    "text_columns": TEXT_COLS_PREFERRED,
    "catalog_source": str(CATALOG_PATH),
    "sklearn_version": __import__("sklearn").__version__,
}
meta_path.write_text(json.dumps(meta, indent=2), encoding="utf-8")

print("Saved:", artifacts_path)
print("Saved:", meta_path)
# Out:
# Saved: c:\Users\Jed\Desktop\9raya\ML\models\content_based\tfidf_artifacts.joblib
# Saved: c:\Users\Jed\Desktop\9raya\ML\models\content_based\tfidf_metadata.json

# %%
from pathlib import Path
import re
import numpy as np
import pandas as pd
import joblib
from sklearn.metrics.pairwise import cosine_similarity

ARTIFACTS_PATH = Path.cwd().parent / "models" / "content_based" / "tfidf_artifacts.joblib"
assert ARTIFACTS_PATH.exists(), f"Missing: {ARTIFACTS_PATH}"

bundle = joblib.load(ARTIFACTS_PATH)
vectorizer2 = bundle["vectorizer"]
X2 = bundle["X"]
catalog2 = bundle["catalog"]  # minimal catalog saved during export
feature_names2 = np.array(vectorizer2.get_feature_names_out())

def clean_text2(s: str) -> str:
    s = str(s) if s is not None else ""
    s = s.replace("\uFFFD", " ")
    s = re.sub(r"\s+", " ", s).strip().lower()
    return s

def top_overlap_terms2(query_vec, item_vec, top_n=8):
    overlap = query_vec.multiply(item_vec)
    if overlap.nnz == 0:
        return []
    coo = overlap.tocoo()
    idx = np.argsort(coo.data)[::-1][:top_n]
    return feature_names2[coo.col[idx]].tolist()

def recommend_loaded(query: str, top_k=10):
    q = clean_text2(query)
    qv = vectorizer2.transform([q])
    sims = cosine_similarity(qv, X2).ravel()
    top_idx = np.argsort(sims)[::-1][:top_k]
    out = catalog2.iloc[top_idx].copy()
    out["score"] = sims[top_idx]
    out["why_keywords"] = [", ".join(top_overlap_terms2(qv, X2[i], top_n=8)) for i in top_idx]
    return out.reset_index(drop=True)

print("Loaded:", ARTIFACTS_PATH)
print("Catalog rows:", len(catalog2), "TF-IDF shape:", X2.shape)

display(recommend_loaded("math python", top_k=5))
# Out:
# Loaded: c:\Users\Jed\Desktop\9raya\ML\models\content_based\tfidf_artifacts.joblib
# Catalog rows: 3408 TF-IDF shape: (3408, 53323)
#    course_id                             Course Name  \
# 0        354                Data Science Math Skills
# 1        111  Improving Math Engagement with Prodigy
# 2       2263                    Python Data Analysis
# 3       2579                   Math behind Moneyball
# 4         16           Python Programming Essentials
#
#                  University Difficulty Level  Course Rating  \
# 0           Duke University       Conversant            4.4
# 1  Coursera Project Network         Beginner            4.8
# 2           Rice University         Advanced            4.6
# 3     University of Houston         Advanced            4.2
# 4           Rice University         Beginner            4.8
#
#                                           Course URL  \
# 0  https://www.coursera.org/learn/datasciencemath...
# 1    https://www.coursera.org/learn/teaching-prodigy
# 2     https://www.coursera.org/learn/python-analysis
# 3   https://www.coursera.org/learn/mathematics-sport
# 4  https://www.coursera.org/learn/python-programming
#
#                                       skills_cleaned     score why_keywords
# 0  general statistics  probability  euler's totie...  0.438081         math
# 1  accounting  mathematics  child  strategy  proj...  0.384888         math
# 2  data visualization  jpeg  python programming  ...  0.275204       python
# 3  regression  sports  microsoft excel  mathemati...  0.267617         math
# 4  semantics  python programming  problem solving...  0.264439       python

# %%
# Evaluate content-based model using user_interactions.csv (leave-one-out per user)
import time
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import normalize
import scipy.sparse as sp

K = 10
MAX_USERS = 5000  # set None for all users; keep small if it runs slow
RANDOM_SEED = 42

# Prefer exported artifacts if loaded; otherwise fall back to in-memory objects
X_eval = X2 if "X2" in globals() else X
catalog_eval = (
    catalog2
    if "catalog2" in globals()
    else df[["course_id", "Course Name", "University", "Difficulty Level", "Course Rating", "Course URL", "skills_cleaned"]].copy()
 )
course_ids = catalog_eval["course_id"].astype(int).to_numpy()
id_to_index = {int(cid): i for i, cid in enumerate(course_ids)}
valid_course_ids = set(int(x) for x in course_ids)

INTERACTIONS_PATH = Path.cwd().parent / "data" / "processed" / "user_interactions.csv"
assert INTERACTIONS_PATH.exists(), f"Missing: {INTERACTIONS_PATH}"
inter = pd.read_csv(INTERACTIONS_PATH)
print("Interactions shape:", inter.shape)
print("Interactions columns:", list(inter.columns))

# Guess user and item columns
lower = {c.lower(): c for c in inter.columns}
def pick_col(candidates):
    for cand in candidates:
        for lc, orig in lower.items():
            if lc == cand or lc.endswith(cand) or cand in lc:
                return orig
    return None

user_col = pick_col(["user_id", "userid", "user"])
item_col = pick_col(["course_id", "program_id", "item_id", "content_id", "course"])
if user_col is None or item_col is None:
    raise ValueError(
        f"Could not infer user/item columns. Found user={user_col}, item={item_col}. Columns={list(inter.columns)}"
    )

# Keep only interactions that map to known course_ids
inter = inter[[user_col, item_col]].dropna()
inter[user_col] = inter[user_col].astype(int)
inter[item_col] = inter[item_col].astype(int)
inter = inter[inter[item_col].isin(valid_course_ids)]
print("After filtering to known courses:", inter.shape)

# Require at least 2 interactions per user to do leave-one-out
counts = inter.groupby(user_col)[item_col].count()
eligible_users = counts[counts >= 2].index.to_numpy()
print("Eligible users (>=2 interactions):", len(eligible_users))
if MAX_USERS is not None and len(eligible_users) > MAX_USERS:
    rng = np.random.default_rng(RANDOM_SEED)
    eligible_users = rng.choice(eligible_users, size=MAX_USERS, replace=False)
    print("Sampled users:", len(eligible_users))

# Build per-user lists of item indices
user_items = (
    inter[inter[user_col].isin(eligible_users)]
    .groupby(user_col)[item_col]
    .apply(lambda s: [id_to_index[int(x)] for x in s.values])
    .to_dict()
 )

t0 = time.perf_counter()
hits = 0
prec_sum = 0.0
ndcg_sum = 0.0
n_eval = 0

for _, items in user_items.items():
    if len(items) < 2:
        continue
    # leave-one-out: last item as test (random would also be OK)
    test_i = items[-1]
    train_items = items[:-1]

    # build user profile as mean of training item vectors
    profile = X_eval[train_items].mean(axis=0)
    profile = profile.tocsr() if sp.issparse(profile) else sp.csr_matrix(profile)
    profile = normalize(profile)

    # cosine similarity = dot product for l2-normalized vectors
    scores = (profile @ X_eval.T).toarray().ravel()
    # exclude training items from ranking
    scores[train_items] = -np.inf

    # top-K indices
    if K >= len(scores):
        top_idx = np.argsort(scores)[::-1]
    else:
        cand = np.argpartition(scores, -K)[-K:]
        top_idx = cand[np.argsort(scores[cand])[::-1]]

    # find position of held-out item if present in top-k
    where = np.where(top_idx == test_i)[0]
    if where.size > 0:
        pos0 = int(where[0])  # 0-based position within top-k
        hits += 1
        prec_sum += 1.0 / K
        ndcg_sum += 1.0 / np.log2(pos0 + 2)  # rank=pos0+1 => DCG = 1/log2(rank+1) = 1/log2(pos0+2)
    n_eval += 1

dt = time.perf_counter() - t0
print("\nEvaluation summary")
print("Users evaluated:", n_eval)
print(f"HitRate@{K}: {hits / max(n_eval, 1):.4f}")
print(f"Precision@{K}: {prec_sum / max(n_eval, 1):.6f}")
print(f"NDCG@{K}: {ndcg_sum / max(n_eval, 1):.6f}")
print("Seconds:", round(dt, 2))
# Out:
# Interactions shape: (11935, 4)
# Interactions columns: ['user_id', 'course_id', 'interaction', 'score']
# After filtering to known courses: (11935, 2)
# Eligible users (>=2 interactions): 600
#
# Evaluation summary
# Users evaluated: 600
# HitRate@10: 0.0067
# Precision@10: 0.000667
# NDCG@10: 0.002797
# Seconds: 6.5
